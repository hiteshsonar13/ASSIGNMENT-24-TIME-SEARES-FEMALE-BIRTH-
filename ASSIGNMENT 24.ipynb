# %% [markdown]
# # FEMALE BIRTHS ASSIGNMENT

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\hitesh sonar\anaconda3\lib\site-packages (0.13.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hitesh sonar\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\hitesh sonar\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
import warnings
warnings.filterwarnings("ignore")
sns.set()

from statsmodels.graphics.api import qqplot
# %matplotlib inline

# %%
female_birth=pd.read_csv("daily-total-female-births-CA.csv")

# %%
female_birth.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
female_birth.tail()
# Out:
#            date  births
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50

# %%
updated_birth=pd.read_csv("daily-total-female-births-CA.csv", index_col=[0], parse_dates=[0])
updated_birth
# Out:
#             births
# date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
updated_birth.head()
# Out:
#             births
# date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
updated_birth.plot()
plt.show()

# %%
average_birth=updated_birth.rolling(window=20).mean()

# %%
average_birth
# Out:
#             births
# date
# 1959-01-01     NaN
# 1959-01-02     NaN
# 1959-01-03     NaN
# 1959-01-04     NaN
# 1959-01-05     NaN
# ...            ...
# 1959-12-27   42.10
# 1959-12-28   42.25
# 1959-12-29   42.50
# 1959-12-30   43.10
# 1959-12-31   43.90
#
# [365 rows x 1 columns]

# %%
average_birth.plot()
plt.show()

# %%
sm.stats.durbin_watson(updated_birth)
# Out:
# array([0.04624491])

# %%
# %matplotlib inline
fig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(updated_birth.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(updated_birth, lags=40, ax=ax2)

# %%
training_data=updated_birth[0:320]
test_data=updated_birth[320:]

# %%
from sklearn.model_selection import train_test_split
t_x,t=train_test_split(updated_birth)

# %%
from statsmodels.tsa.arima_model import ARMA, ARIMA
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
arima= ARIMA(training_data,order=(2,1,3))

# %%
model=arima.fit()

# %%
model.aic
# Out:
# 2167.8472399104467

# %%
pred= model.forecast(steps=45)[0]

# %%
pred
# Out:
# 42.86063948044448

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test_data,pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 np.sqrt(mean_squared_error(test_data,pred))
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:394, in check_consistent_length(*arrays)
#     383 def check_consistent_length(*arrays):
#     384     """Check that all arrays have consistent first dimensions.
#     385
#     386     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     391         Objects that will be checked for consistent length.
#     392     """
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:394, in <listcomp>(.0)
#     383 def check_consistent_length(*arrays):
#     384     """Check that all arrays have consistent first dimensions.
#     385
#     386     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     391         Objects that will be checked for consistent length.
#     392     """
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:335, in _num_samples(x)
#     333 if hasattr(x, "shape") and x.shape is not None:
#     334     if len(x.shape) == 0:
# --> 335         raise TypeError(
#     336             "Singleton array %r cannot be considered a valid collection." % x
#     337         )
#     338     # Check that shape is returning an integer or default to len
#     339     # Dask dataframes may not return numeric shape[0] value
#     340     if isinstance(x.shape[0], numbers.Integral):
#
# TypeError: Singleton array 42.86063948044448 cannot be considered a valid collection.
